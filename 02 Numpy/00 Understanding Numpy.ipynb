# %%
# Broadcasting is a powerful mechanism that allows numpy to work with arrays of different shapes when performing
# The term broadcasting refers to the ability of NumPy to treat arrays of different shapes during arithmetic operations

# %%
# np.tile will repeat a whole list or array n times. Whereas, np.repeat repeats each item n times.

# %%
# np.random.seed : It produces the same sequence of number every time

# %%
#Diff Between rand and randn

# numpy.random.randn generates samples from the normal distribution
# numpy.random.rand from unifrom (in range [0,1)).

# %%
# arange : Values are generated within the half-open interval [start, stop]

# %%
## get help
# print(np.lookfor("mean"))

# %%
## Get info on data types with `np.info()`
# np.info(np.ndarray.dtype)
