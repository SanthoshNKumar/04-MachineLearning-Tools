# %%
'''

Create DataFrame
    - List
    - List of Lists
    - Dictionary
    - List of Dictionary
    - From Dictionary of series.
    - Numpy Array
    - Using zip()
    - Create DataFrame using Random Integer Generator
    - Create DaraFrame using Data Functionality 
        - Date Range,Frequency,start_end,
    - Read from External Files
        - Read from CSV
        - Read from excel
        - read_json
        - StringIO
        
    - Copy the DataFrame
    - Add records to dataframe using the .loc function
    - Creates a indexes for DataFrame using arrays.
    
Basic DataFrame Operations
    - Display the  Data Frame
    - Print information about the data
    - Shape of the Dataframe
    - Print first 5 Rows or Observation
    - Print last 5 Rows or Observation
    - Check Whether the Object is empty or not
    - Check number of dimensions of the object
    - Number of elements in the DataFrame.
    - Returns the actual data in the DataFrame as an ND Array.
    - Transpose of the Dataframe
    - Find any null values in the DataFrame
    - Find the Null values on the data Frame Column wise
    - Find the null values on the data frame row wise
    - Iterate over through the Dataframe

Column Operations
    - Find total columns in the Dataframe
    - Get All the columns on the Data Frame
    - Get the Column Name
    - Check the Data Type of Columns
    - Get Unique values in the Column
    - Get Specific column
    - Get only the Specific Columns
    - Selecting columns by data type
    - Rename a Single Column
    - Rename Columns 
    - Delete column in the DataFrame
    - Add new column in the DataFrame
    - Get the Count of Unique elements in the column
    
Sorting in Columns
    - Ascending
    - Descending
    - Multiple column
    
Row Operations:
    - Add new data on the dataframe
    - Delete rows of data
    - Adding new rows from different dataframe
    - Get only the rows where nulll values on specific column
    
Handling Missing Values:
    - Check if there is any null values
    - Boolean indicator to check whether column having null value
    - Column wise Total null values
    - Total number of missing values in the dataframe
    - Filter and display data where null values are present
    - Filter data based on where no null values present
    - Filter All rows in the dataframe where null values present
    - Drop all rows where Nan values
    - Drop all rows with atleasr one Nan present
    - Drop column with atleast one NaN
    - Replacing NaNs with a single constant value
    - Replacing NaNs using Median/Mean of the column
    - Using the replace method
    - Interpolate() function is used to fill NaN values
    - Forward Fill Missing DataFrame Value
    - Backward Fill Missing DataFrame Values
    - Using SCIKIT Learn Imputer Method
    - Drop Duplicate data in dataframe
    
Cleaning DataFrame
    - Remove Special Characters 
    - Stopward Remove
    
Create Dummpy Varibales
    - using .map
    - pd.get_dummies
    
Indexing in DataFrame 
    - Dataframe.[ ] ; This function also known as indexing operator
    - Dataframe.loc[ ] : This function is used for labels.
    - Dataframe.iloc[ ] : This function is used for positions or integer based
    - Dataframe.ix[] : This function is used for both label and integer based

Filters in Dataframe
    - Filter specific columns
    - Regular Expression
    - Filter row based on single value on the column
    - Filter row based on single value on the column using Boolean Expression
    - Filter row based on the column does not equal to Some value 
    - Filter rows based on values are not NA/NAN
    - Select rows based on whose values is in the list
    - Between
    - Negation(~)
    - Applying Multiple Condidtion 
    - Filter and look only for Specific Column
    - Filter and look only for Specific Column using loc
    - Filter Row based on Indexer
    
GroupBy
    - groups : 
    - ngroups : get the number of groups
    - size :  compute and display group sizes
    - get_group : retrieve one of the created groups
    - Aggregation in Grouped Column
    - Apply filters on Grouped daata
    - https://towardsdatascience.com/all-pandas-groupby-you-should-know-for-grouping-data-and-performing-operations-2a8ec1327b5

    
Statistic Operation
    - Describe
    - sum
    - count #Number of non-null observations
    - mean
    - median
    - ode
    - std
    - min
    - max
    - abs
    - prob
    - cumsum # Cumulative Sum
    - cumprob # Cumulative Product

Advanced Dataframe Operations
    - Merge Two DataFrame
    - Join
    - Concat
