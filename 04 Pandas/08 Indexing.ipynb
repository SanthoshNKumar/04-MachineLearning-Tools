# %%
# Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame.

# %%
# loc is label-based, which means that you have to specify rows and columns based on their row and column labels.

# iloc is integer position-based, so you have to specify rows and columns by their integer position values 
# (0-based integer position).

# %%
# loc and iloc are interchangeable when labels are 0-based integers
# df = pd.read_csv('data/data.csv', header=None, skiprows=[0],)

# %%
# loc is label-based, which means that we have to specify the name of the rows and columns that we need to filter out.

# iloc is integer index-based. So here, we have to specify rows and columns by their integer index.

# %%
'''
Indexing in DataFrame 
    - Dataframe.[ ] ; This function also known as indexing operator
    - Dataframe.loc[ ] : This function is used for labels.
    - Dataframe.iloc[ ] : This function is used for positions or integer based
    - Dataframe.ix[] : This function is used for both label and integer based

# %% [markdown]
# ![indexing%20in%20pandas.png](attachment:indexing%20in%20pandas.png)

# %% [markdown]
# ![1234.png](attachment:1234.png)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
#5 Creating Dataframe from list of dicts

data = [{'Name': 'Santhosh', 'Age':32, 'Company':'Microsft'},
        {'Name': 'Anand', 'Age':34, 'Company':'Google'},
        {'Name': 'Sreedevi', 'Age':31, 'Company':'Facebook'},
        {'Name': 'Prashanth', 'Age':30, 'Company':'Testla'},
        {'Name': 'Sachin', 'Age':35, 'Company':'Volvo'}]

df = pd.DataFrame(data)

df
# Out:
#         Name  Age   Company
# 0   Santhosh   32  Microsft
# 1      Anand   34    Google
# 2   Sreedevi   31  Facebook
# 3  Prashanth   30    Testla
# 4     Sachin   35     Volvo

# %% [markdown]
# ## Indexing a Dataframe using indexing operator [] :

# %%
# retrieving columns by indexing operator

first = df["Age"]

first
# Out:
# 0    32
# 1    34
# 2    31
# 3    30
# 4    35
# Name: Age, dtype: int64

# %%
# retrieving multiple columns by indexing operator

# Select all row with column of 'Name' and 'Age'
first = df[["Name", "Age"]]

first
# Out:
#         Name  Age
# 0   Santhosh   32
# 1      Anand   34
# 2   Sreedevi   31
# 3  Prashanth   30
# 4     Sachin   35

# %% [markdown]
# ## Indexing a DataFrame using .loc[ ] : for labels

# %%
# This function selects data by the label of the rows and columns

# Syntax : loc[row_label, column_label]

# %%
#1 :Format : df.loc[rows,column]
    #2 :df.loc[0,:]  :- Row 0 and all columns
    #3 :df.loc[[0,1,2],:]  :- rows 0,1,2 and all columns
    #4 :df.loc[0:2,:]  :- rows 0,1,2 and All columns
    #5 :df.loc[0:2] :-rows 0,1,2 and all columns
    #6 :df.loc[:,'City'] :- All rows and Column 'City'
    #7 :df.loc[:,['City','State']] :- All rows and Coumns 'City' and 'State'
    #8 :df.loc[:,'City' : 'State'] : All rows and Columns from City to State
    #9 :df.loc[0:2,'City':'State'] : Multiple rows and Columsn
    #10:df.loc[df.city == 'Banglore',:]
    #11:df.loc[ufo.City=='Oakland', 'State'] : Rows which have city value('Oakland') and column 'State'

# %%
df.loc[:,:]  # all the row and column
# Out:
#         Name  Age   Company
# 0   Santhosh   32  Microsft
# 1      Anand   34    Google
# 2   Sreedevi   31  Facebook
# 3  Prashanth   30    Testla
# 4     Sachin   35     Volvo

# %%
df.loc[[0,1,2],:]  # get rows of index 0,1,2, and all columns
# Out:
#        Name  Age   Company
# 0  Santhosh   32  Microsft
# 1     Anand   34    Google
# 2  Sreedevi   31  Facebook

# %%
df.loc[0:2,:]  # get rows from 0th to 2nd index and All column
# Out:
#        Name  Age   Company
# 0  Santhosh   32  Microsft
# 1     Anand   34    Google
# 2  Sreedevi   31  Facebook

# %%
df.loc[0:2] # get rows from 0th to 2nd index and all column
# Out:
#        Name  Age   Company
# 0  Santhosh   32  Microsft
# 1     Anand   34    Google
# 2  Sreedevi   31  Facebook

# %%
df.loc[:,'Age'] # all rows and Column 'Age'
# Out:
# 0    32
# 1    34
# 2    31
# 3    30
# 4    35
# Name: Age, dtype: int64

# %%
df.loc[:,['Name','Age']]  # all row and colums 'Name' and 'Age'
# Out:
#         Name  Age
# 0   Santhosh   32
# 1      Anand   34
# 2   Sreedevi   31
# 3  Prashanth   30
# 4     Sachin   35

# %%
df.loc[0:2,['Name','Age']] # Rows of index 0,1,2 and columns Name and Age
# Out:
#        Name  Age
# 0  Santhosh   32
# 1     Anand   34
# 2  Sreedevi   31

# %%
df.loc[:,'Name':'Age'] # All the rows and column from 'Name' to Age
# Out:
#         Name  Age
# 0   Santhosh   32
# 1      Anand   34
# 2   Sreedevi   31
# 3  Prashanth   30
# 4     Sachin   35

# %%
df.loc[:,'Name':'Company'] # All the rows and column from 'Name' to Company
# Out:
#         Name  Age   Company
# 0   Santhosh   32  Microsft
# 1      Anand   34    Google
# 2   Sreedevi   31  Facebook
# 3  Prashanth   30    Testla
# 4     Sachin   35     Volvo

# %%
df.loc[df.Company == 'Google',:]  # All rows where company is google and al columns
# Out:
#     Name  Age Company
# 1  Anand   34  Google

# %%
df.loc[df.Company =='Google','Name']   # get ethe name column from where row having company is google
# Out:
# 1    Anand
# Name: Name, dtype: object

# %%
df = pd.read_csv("data.csv", index_col=['Day'])

df
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Tue   Sunny        19.67    28        96
# Wed   Sunny        17.51    16        20
# Thu  Cloudy        14.44    11        22
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62
# Sun   Sunny        17.50    20        10

# %%
df.loc['Fri','Temperature'] # set index_col=['Day'] # get temperature of friday
# Out:
# 10.51

# %%
df.iloc[4,1]  # get the value from the dataframe where row index is 4 and column is 1
# Out:
# 10.51

# %%
# To get all rows
# : to return all data.

df.loc[:,'Temperature'] # Select all row and column of Temperature
# Out:
# Day
# Mon    12.79
# Tue    19.67
# Wed    17.51
# Thu    14.44
# Fri    10.51
# Sat    11.07
# Sun    17.50
# Name: Temperature, dtype: float64

# %%
df.iloc[:, 1] # Select all the row and Column indecies of 1 i.e temperature
# Out:
# Day
# Mon    12.79
# Tue    19.67
# Wed    17.51
# Thu    14.44
# Fri    10.51
# Sat    11.07
# Sun    17.50
# Name: Temperature, dtype: float64

# %%
# To get all columns
df.loc['Fri',:] # slect row value of 'Friday' and All column
# Out:
# Weather        Shower
# Temperature     10.51
# Wind               26
# Humidity           79
# Name: Fri, dtype: object

# %%
df.iloc[4, :] # get all the column values for the row indices of 4
# Out:
# Weather        Shower
# Temperature     10.51
# Wind               26
# Humidity           79
# Name: Fri, dtype: object

# %% [markdown]
# ### Selecting via a list of values

# %%
df.loc[['Thu', 'Fri'], 'Temperature'] # Select row values  for 'Thu' and 'Friday' and column of 'Temperature'
# Out:
# Day
# Thu    14.44
# Fri    10.51
# Name: Temperature, dtype: float64

# %%
df.iloc[[3, 4], 1]
# Out:
# Day
# Thu    14.44
# Fri    10.51
# Name: Temperature, dtype: float64

# %%
# Multiple rows and columns
rows = ['Thu', 'Fri']
cols=['Temperature','Wind']

df.loc[rows, cols]
# Out:
#      Temperature  Wind
# Day
# Thu        14.44    11
# Fri        10.51    26

# %%
rows = [3, 4]
cols = [1, 2]
df.iloc[rows, cols]
# Out:
#      Temperature  Wind
# Day
# Thu        14.44    11
# Fri        10.51    26

# %% [markdown]
# ### Selecting a range of data via slice

# %%
# Slicing column labels
rows=['Thu', 'Fri']
df.loc[rows, 'Temperature':'Humidity' ]
# Out:
#      Temperature  Wind  Humidity
# Day
# Thu        14.44    11        22
# Fri        10.51    26        79

# %%
# Slicing row labels
cols = ['Temperature', 'Wind']

df.loc['Mon':'Thu', cols]
# Out:
#      Temperature  Wind
# Day
# Mon        12.79    13
# Tue        19.67    28
# Wed        17.51    16
# Thu        14.44    11

# %%
# Slicing with step
# A:B:S : A to label B with step size S 

df.loc['Mon':'Fri':2 , :]  # Monday to Friday with Step of 2 for rows and All columns
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Wed   Sunny        17.51    16        20
# Fri  Shower        10.51    26        79

# %%
df
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Tue   Sunny        19.67    28        96
# Wed   Sunny        17.51    16        20
# Thu  Cloudy        14.44    11        22
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62
# Sun   Sunny        17.50    20        10

# %% [markdown]
# ### Selecting via conditions

# %%
# One condition
df.loc[df.Humidity > 50, :]  #  rows where 'Humidity' > 50 and Select All columns
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %%
# Select only required columns with a condition

# Multiple condition for row selection and column of ['Temperature','Wind']
df.loc[(df.Humidity > 50) & (df.Weather == 'Shower'), ['Temperature','Wind']]
# Out:
#      Temperature  Wind
# Day
# Fri        10.51    26
# Sat        11.07    27

# %%
# Callable function

# Selecting columns
df.loc[:, lambda df: ['Humidity', 'Wind']] # Select all rows for column of 'Humidity' abnd 'Wind'
# Out:
#      Humidity  Wind
# Day
# Mon        30    13
# Tue        96    28
# Wed        20    16
# Thu        22    11
# Fri        79    26
# Sat        62    27
# Sun        10    20

# %%
# With condition
df.loc[lambda df: df.Humidity > 50, :] # Select row of conditiona of where Humidity > 50 and all columns
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %%
import numpy as np
# crete a sample dataframe
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', np.NAN, 'yellow', np.NAN, 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data.loc[(data.age >= 12), ['section']]
# Out:
#   section
# 1       B
# 2       C
# 3       B
# 4       B
# 6       A

# %%
# update a column with condition
data.loc[(data.age >= 12), ['section']] = 'M'
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       M    Delhi      F             NaN
# 2   13       M   Mumbai      F          yellow
# 3   21       M    Delhi      M             NaN
# 4   12       M   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       M   Mumbai      F             red

# %%
# Update the values of multiple columns on selected rows

# update multiple columns with condition
data.loc[(data.age >= 20), ['section', 'city']] = ['S','Pune']
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       S     Pune      F             NaN
# 2   13       M   Mumbai      F          yellow
# 3   21       S     Pune      M             NaN
# 4   12       M   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       M   Mumbai      F             red

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
data.loc[['Andrade', 'Veness'], 'city':'email']

# Select same rows, with just 'first_name', 'address' and 'city' columns
data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
 
# Change the index to be based on the 'id' column
data.set_index('id', inplace=True)

# select the row with 'id' = 487
data.loc[487]

# %%
# Select rows with first name Antonio, # and all columns between 'city' and 'email'
data.loc[data['first_name'] == 'Antonio', 'city':'email']
 
# Select rows where the email column ends with 'hotmail.com', include all columns
data.loc[data['email'].str.endswith("hotmail.com")]   
 
# Select rows with last_name equal to some values, all columns
data.loc[data['first_name'].isin(['France', 'Tyisha', 'Eric'])]   
       
# Select rows with first name Antonio AND hotmail email addresses
data.loc[data['email'].str.endswith("gmail.com") & (data['first_name'] == 'Antonio')] 
 
# select rows with id column between 100 and 200, and just return 'postal' and 'web' columns
data.loc[(data['id'] > 100) & (data['id'] <= 200), ['postal', 'web']] 
 
# A lambda function that yields True/False values can also be used.
# Select rows where the company name has 4 words in it.
data.loc[data['company_name'].apply(lambda x: len(x.split(' ')) == 4)] 
 
# Selections can be achieved outside of the main .loc for clarity:
# Form a separate variable with your selections:
idx = data['company_name'].apply(lambda x: len(x.split(' ')) == 4)
# Select only the True values in 'idx' and only the 3 columns specified:
data.loc[idx, ['email', 'first_name', 'company']]

# %%
# Setting value in the dataframe

# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"

# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"

# %% [markdown]
# ## Indexing a DataFrame using .iloc[ ] : for Integer

# %%
# This function is used for positions or integer based

# %%
    #12:df.iloc[:, [0, 3]]
    #13:df.iloc[:, 0:4]
    #14:df.iloc[0:3, :]
    #15:df[['City', 'State']] : # non-explicit code
    #16:df.loc[:, ['City', 'State']] : # explicit code
    #17:df.iloc[0:2, :]

# %%
# Filter Based on the row and Column Position

    #df.iloc[:]  # Select all the row and Column in the dataframe
    #df.iloc[1:5,] #Second to Fifith Row
    #df.iloc[5,0] # Sixth row and 1st Column  output : single value (Cell value)
    #df.iloc[1:5,0] # Second to Fifth row and First Column
    #df.iloc[1:5,:5] # Second to Fifth row, first 5 Columns
    #df.iloc[2:7,1:3] # Third to Seventh row,2nd and 3rd Column

# %%
df = pd.read_csv("data.csv", )
df
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 0  Mon   Sunny        12.79    13        30
# 1  Tue   Sunny        19.67    28        96
# 2  Wed   Sunny        17.51    16        20
# 3  Thu  Cloudy        14.44    11        22
# 4  Fri  Shower        10.51    26        79
# 5  Sat  Shower        11.07    27        62
# 6  Sun   Sunny        17.50    20        10

# %% [markdown]
# ##### row selction

# %%
data.iloc[0] # first row of data frame
# Out:
# age                     10
# section                  A
# city               Gurgaon
# gender                   M
# favourite_color        red
# Name: 0, dtype: object

# %%
data.iloc[1] # second row of data frame
# Out:
# age                  22
# section               S
# city               Pune
# gender                F
# favourite_color     NaN
# Name: 1, dtype: object

# %%
data.iloc[-1] # last row of data frame
# Out:
# age                    17
# section                 M
# city               Mumbai
# gender                  F
# favourite_color       red
# Name: 6, dtype: object

# %% [markdown]
# ##### column Selection

# %%
data.iloc[:,0] # first column of data frame (first_name)
# Out:
# 0    10
# 1    22
# 2    13
# 3    21
# 4    12
# 5    11
# 6    17
# Name: age, dtype: int64

# %%
data.iloc[:,1] # second column of data frame (last_name)
# Out:
# 0    A
# 1    S
# 2    M
# 3    S
# 4    M
# 5    A
# 6    M
# Name: section, dtype: object

# %%
data.iloc[:,-1] # last column of data frame (id)
# Out:
# 0       red
# 1       NaN
# 2    yellow
# 3       NaN
# 4     black
# 5     green
# 6       red
# Name: favourite_color, dtype: object

# %% [markdown]
# #### Multiple row and column selections using iloc and DataFrame

# %%
data.iloc[0:5] # first five rows of dataframe
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       S     Pune      F             NaN
# 2   13       M   Mumbai      F          yellow
# 3   21       S     Pune      M             NaN
# 4   12       M   Mumbai      M           black

# %%
data.iloc[:, 0:2] # first two columns of data frame with all rows
# Out:
#    age section
# 0   10       A
# 1   22       S
# 2   13       M
# 3   21       S
# 4   12       M
# 5   11       A
# 6   17       M

# %%
data.iloc[[1,3,5], [0,4,3]] # 1st, 3rd, 5th row + 0th, 4th 73rd columns.
# Out:
#    age favourite_color gender
# 1   22             NaN      F
# 3   21             NaN      M
# 5   11           green      M

# %%
data.iloc[0:5, 1:3] # first 5 rows and 1st, 2nd, 3rd columns of data frame (county -> phone1).
# Out:
#   section     city
# 0       A  Gurgaon
# 1       S     Pune
# 2       M   Mumbai
# 3       S     Pune
# 4       M   Mumbai

# %%
# Select rows with indices using iloc
df.iloc[[0,2]]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 0  Mon   Sunny        12.79    13        30
# 2  Wed   Sunny        17.51    16        20

# %%
# Select rows with particular indices and particular columns
df.iloc[[0,2],[1,3]]
# Out:
#   Weather  Wind
# 0   Sunny    13
# 2   Sunny    16

# %%
# Select a range of rows using iloc
df.iloc[1:3]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 1  Tue   Sunny        19.67    28        96
# 2  Wed   Sunny        17.51    16        20

# %%
# Select a range of rows and columns using iloc

df.iloc[1:3,2:4]
# Out:
#    Temperature  Wind
# 1        19.67    28
# 2        17.51    16

# %%
df.iloc[:, [0, 3]]  # all the rows but column of 0 and 3 index
# Out:
#    Day  Wind
# 0  Mon    13
# 1  Tue    28
# 2  Wed    16
# 3  Thu    11
# 4  Fri    26
# 5  Sat    27
# 6  Sun    20

# %%
df.iloc[:, 0:4]  # all the rows but column index from 0 to 4
# Out:
#      0       1      2   3
# 0  Mon   Sunny  12.79  13
# 1  Tue   Sunny  19.67  28
# 2  Wed   Sunny  17.51  16
# 3  Thu  Cloudy  14.44  11
# 4  Fri  Shower  10.51  26
# 5  Sat  Shower  11.07  27
# 6  Sun   Sunny  17.50  20

# %%
df.iloc[0:3, :]  # rows from 0 to 3rd index and all the columns
# Out:
#      0      1      2   3   4
# 0  Mon  Sunny  12.79  13  30
# 1  Tue  Sunny  19.67  28  96
# 2  Wed  Sunny  17.51  16  20

# %%
# Single condition
df.iloc[list(df.Humidity > 50),:]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 1  Tue   Sunny        19.67    28        96
# 4  Fri  Shower        10.51    26        79
# 5  Sat  Shower        11.07    27        62

# %%
# Multiple Condition
df.iloc[list((df.Humidity > 50) & (df.Weather == 'Shower')),:,]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 4  Fri  Shower        10.51    26        79
# 5  Sat  Shower        11.07    27        62

# %%
# Callable Function
df.iloc[lambda df: [0,1], :]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 0  Mon   Sunny        12.79    13        30
# 1  Tue   Sunny        19.67    28        96

# %%
df.iloc[lambda df: list(df.Humidity > 50), :]
# Out:
#    Day Weather  Temperature  Wind  Humidity
# 1  Tue   Sunny        19.67    28        96
# 4  Fri  Shower        10.51    26        79
# 5  Sat  Shower        11.07    27        62

# %%
import pandas as pd

df = pd.read_csv("Titanic_train.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[1:5,] #Second to Fifith Row and all the columns
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[5,0] # Sixth row and 1st Column  output : single value (Cell value)
# Out:
# 6

# %%
df.iloc[1:5,0] # Second to Fifth row and First Column
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# Name: PassengerId, dtype: int64

# %%
df.iloc[1:5,:5] # Second to Fifth row, first 5 Columns
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df.iloc[2:7,1:3] # Third to Seventh row,2nd and 3rd Column
# Out:
#    Survived  Pclass
# 2         1       3
# 3         1       1
# 4         0       3
# 5         0       3
# 6         0       1

# %%
import numpy as np
x = pd.DataFrame({"col1" : np.arange(1,20,2)}, index=[9,8,7,6,0, 1, 2, 3, 4, 5])

x
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19

# %%
x.iloc[0:5]  # Selecting rows based on index or row position
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9

# %%
x.loc[0:5] # Selecting rows based on labels of index
# Out:
#    col1
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19

# %%
df.loc[[2]] # Index based
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
# fILTER ROW BASED ON INDEXER

df.iloc[[-1]]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
# Selecting a scalar value
df.iloc[3,4] # Row number and Column number
# Out:
# 'female'

# %%
df.loc[3,'Sex'] # Row number and 'Column' name
# Out:
# 'female'

# %%
df.iloc[34,[0,3,4]]  # 34th row and values of column 'passenger Id' 'Name' and 'Sex'
# Out:
# PassengerId                         35
# Name           Meyer, Mr. Edgar Joseph
# Sex                               male
# Name: 34, dtype: object

# %%
df.loc[34,['PassengerId','Name','Sex']]
# Out:
# PassengerId                         35
# Name           Meyer, Mr. Edgar Joseph
# Sex                               male
# Name: 34, dtype: object

# %%
df.loc[0,:] # Row 0 and all Columns
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.loc[[0,1,2],:] # row 0,1,2 and all columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[0:2,:] #from row 0th to 2nd and all columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[0:2] # from row 0th to 2nd and all columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[:,'Fare'] # All the row and Column 'Fare'
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.loc[:,['Fare','Ticket']] # all the row and Column 'Fare' and 'Ticket'
# Out:
#         Fare            Ticket
# 0     7.2500         A/5 21171
# 1    71.2833          PC 17599
# 2     7.9250  STON/O2. 3101282
# 3    53.1000            113803
# 4     8.0500            373450
# ..       ...               ...
# 886  13.0000            211536
# 887  30.0000            112053
# 888  23.4500        W./C. 6607
# 889  30.0000            111369
# 890   7.7500            370376
#
# [891 rows x 2 columns]

# %%
df.loc[:,'Pclass':'Parch'] # All the row and Column from 'Pclass' to 'Parch'
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch
# 0        1      0
# ...

# %%
df.loc[5:14,'Pclass':'Parch'] # row from 5th to 14 and Column from 'Pclass' to 'Parch'
# Out:
#     Pclass                                               Name     Sex   Age  \
# 5        3                                   Moran, Mr. James    male   NaN
# 6        1                            McCarthy, Mr. Timothy J    male  54.0
# 7        3                     Palsson, Master. Gosta Leonard    male   2.0
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 11       1                           Bonnell, Miss. Elizabeth  female  58.0
# 12       3                     Saundercock, Mr. William Henry    male  20.0
# 13       3                        Andersson, Mr. Anders Johan    male  39.0
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
#
#     SibSp  Parch
# 5       0      0
# 6       0      0
# 7       3      1
# 8       0      2
# 9       1      0
# 10      1      1
# ...

# %%
df.loc[df.Sex =='male',:] # get all the row where Sex is 'male' and All columns
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# loc is an abbreviation of location term

df.loc[(df.Embarked =='S') & (df.Sex == 'male')].head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 6       0      0      17463  51.8625   E46        S
# 7       3      1     349909  21.0750   NaN        S
# 12      0      0  A/5. 2151   8.0500   NaN        S

# %%
# Filter and look only for Specific Column using loc

df.loc[df.Embarked =='S','Name']
# Out:
# 0                           Braund, Mr. Owen Harris
# 2                            Heikkinen, Miss. Laina
# 3      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                          Allen, Mr. William Henry
# 6                           McCarthy, Mr. Timothy J
#                            ...
# 883                   Banfield, Mr. Frederick James
# 884                          Sutehall, Mr. Henry Jr
# 886                           Montvila, Rev. Juozas
# 887                    Graham, Miss. Margaret Edith
# 888        Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 644, dtype: object

# %%
# loc and iloc are interchangeable when labels are 0-based integers
# df = pd.read_csv('data/data.csv', header=None, skiprows=[0],)

# %%
df = pd.read_csv('data.csv', header=None, skiprows=[0],)

dfdf.loc[1, 2]
# Out:
#      0       1      2   3   4
# 0  Mon   Sunny  12.79  13  30
# 1  Tue   Sunny  19.67  28  96
# 2  Wed   Sunny  17.51  16  20
# 3  Thu  Cloudy  14.44  11  22
# 4  Fri  Shower  10.51  26  79
# 5  Sat  Shower  11.07  27  62
# 6  Sun   Sunny  17.50  20  10

# %%
df.loc[1, 2]   # generally loc is for labels now it is accepting integer
# Out:
# 19.67

# %%
df.loc[1, [1, 2]]
# Out:
# 1    Sunny
# 2    19.67
# Name: 1, dtype: object

# %% [markdown]
# ## Indexing a using Dataframe.ix[ ] :

# %%
# DataFrame.ix[ ] is both Label and Integer based slicing technique.

# %%
    #19:df.ix['Albania', 0]
    #20:df.ix[1, 'beer_servings']
    #21:df.ix['Albania':'Andorra', 0:2]
    #22:df.ix[0:2, 0:2]

# %%
import pandas as pd
    
# making data frame from csv file
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")  

data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
x1 = data.ix[:4, ]
x1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-224-8c69a4d38cc2> in <module>
# ----> 1 x1 = data.ix[:4, ]
#       2 x1
#
# c:\users\bmi_cims\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
