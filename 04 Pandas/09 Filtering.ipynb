# %%
'''
Filters
    - By Multiple Column Selection
    - using eq Function
    - Equal
    - Not Equal
    - And 
    - or
    - Between 
    - Negation :Tilde(~)
    - notnull
    - isin
    - Filter and look only for Specific Column
    - Condition and Multiple Condition
    - String Contains Function
    - row and column Labels and indices (.loc and .iloc)

# %%
'''
1. Logical operators
    ex: df[df.val > 0.5]
2. Multiple logical operators
    ex: df[(df.val > 0.5) & (df.val2 == 1)]
3. Isin
    ex: df[df.name.isin(['Santhosh','Anand'])]
4. Regular Expression
5. Tilde (~)
6. Between
7. Where
4. Str accessor
    - contains,startswith
9. Nlargest or nsmallest
10. Multiple Conditions
8. Query
    - df.query('ctg == "B" and val > 0.5')
10. Loc and iloc
11. Lambda Methods
12. List Comprehensions

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Titanic_train.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Column selection on DataFrame

df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# df.filter(like='bbi', axis=0)

# %%
# Top 3 Largest Values in fare Column
df.nlargest(3, 'Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
# Top 3 smallest Values in fare Column
df.nsmallest(3, 'Fare')
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 179          180         0       3           Leonard, Mr. Lionel  male  36.0
# 263          264         0       1         Harrison, Mr. William  male  40.0
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 179      0      0    LINE   0.0   NaN        S
# 263      0      0  112059   0.0   B94        S
# 271      0      0    LINE   0.0   NaN        S

# %%
# Apply Filter Function 

# Filter DataFrme Selecting only Columns 'Pclass' 'Name' and 'Sex'
df.filter(['Pclass','Name','Sex']).head()
# Out:
#    Pclass                                               Name     Sex
# 0       3                            Braund, Mr. Owen Harris    male
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male

# %%
# Using Regular Expression

# columns which has letter 'a' or 'A' in its name.
df.filter(regex='[aA]').head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#     Age  Parch     Fare Cabin Embarked
# 0  22.0      0   7.2500   NaN        S
# 1  38.0      0  71.2833   C85        C
# 2  26.0      0   7.9250   NaN        S
# 3  35.0      0  53.1000  C123        S
# 4  35.0      0   8.0500   NaN        S

# %%
# Filter rows of Dataframe based on a Single Value of Column

df[df['Embarked'] == 'S'].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 6             17463  51.8625   E46        S

# %%
# Filter rows of Dataframe based on a Single Value of Column using boolean Expression

df[df.Embarked.eq('S')].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 6             17463  51.8625   E46        S

# %%
# filter rows for year does not equal to Some value 

df[df['Embarked'] !='S'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 5             6         0       3
# 9            10         1       2
# 16           17         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 5       0    330877   8.4583   NaN        Q
# 9       0    237736  30.0708   NaN        C
# 16      1    382652  29.1250   NaN        Q
# 19      0      2649   7.2250   NaN        C

# %%
# filter rows for year does not equal to Some value 
df[df.Embarked !='S'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 5             6         0       3
# 9            10         1       2
# 16           17         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 5       0    330877   8.4583   NaN        Q
# 9       0    237736  30.0708   NaN        C
# 16      1    382652  29.1250   NaN        Q
# 19      0      2649   7.2250   NaN        C

# %%
# filter out rows ina . dataframe with column year values NA/NAN

df[df.Cabin.notnull()].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
#To select rows whose column value is in list

print(df.Embarked.unique())

df[df.Embarked.isin(['S','Q'])].head()
# Out:
# ['S' 'C' 'Q' nan]
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
# Between

df[df['Age'].between(30,50)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 13           14         0       3
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 4       0    373450   8.0500   NaN        S
# 13      5    347082  31.2750   NaN        S
# 18      0    345763  18.0000   NaN        S

# %%
# Negation(~)

# Filter rows based on the condistion Embarked is not 'S'

df[~(df.Embarked=='S')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 5             6         0       3
# 9            10         1       2
# 16           17         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 5       0    330877   8.4583   NaN        Q
# 9       0    237736  30.0708   NaN        C
# 16      1    382652  29.1250   NaN        Q
# 19      0      2649   7.2250   NaN        C

# %%
# Filter with multiple Condidtion wher Embarked is not 'S' and Sex is not 'Male'

df[~(df.Embarked =='S') & ~(df.Sex =='male')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 22           23         1       3
# 28           29         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 9       0    237736  30.0708   NaN        C
# 19      0      2649   7.2250   NaN        C
# 22      0    330923   8.0292   NaN        Q
# 28      0    330959   7.8792   NaN        Q

# %%
# Filter and look only for Specific Column
df[df.Embarked =='S']['PassengerId'].head()
# Out:
# 0    1
# 2    3
# 3    4
# 4    5
# 6    7
# Name: PassengerId, dtype: int64

# %%
# String Methods (str accessor)

df[df.Sex.str.contains('female')].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# str accessor

# Select rows having values starting from letter 'A'
# df[df['var1'].str[0] == 'A']

# Filter rows having string length greater than 3
# df[df['var1'].str.len()>3]

# Select string containing letters A or B
# df[df['var1'].str.contains('A|B')]

# Str accessor
# df[df.name.str.startswith('J')]

# %%
df[(df.Embarked =='S') & (df.Sex == 'male')].head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 6       0      0      17463  51.8625   E46        S
# 7       3      1     349909  21.0750   NaN        S
# 12      0      0  A/5. 2151   8.0500   NaN        S

# %%
# Filter dataframe based on .loc and .iloc Index methods

# %%
# Select rows whose column value does not equal a specific value
# df.loc[(df.origin != "JFK") & (df.carrier == "B6")]

# Filter pandas dataframe by rows position and column names
# df.loc[df.index[0:5],["origin","dest"]]

# columns which has letter 'a' or 'A' in its name.
# df.filter(regex='[aA]').head()

# Filter rows of Dataframe based on a Single Value of Column
# df[df['Embarked'] == 'S']

# Filter rows of Dataframe based on a Single Value of Column using boolean Expression
# df[df.Embarked.eq('S')]

# filter rows for year does not equal to Some value 
# df[df['Embarked'] !='S']

# filter rows for year does not equal to Some value 
# df[df.Embarked !='S']

# filter out rows ina . dataframe with column year values NA/NAN
# df[df.Cabin.notnull()]

# Selecting multiple values of a column
# Long Way
# newdf = df.loc[(df.origin == "JFK") | (df.origin == "LGA")]

# Smart Way
# newdf = df[df.origin.isin(["JFK", "LGA"])]

# %%
# Filter Based on the row and Column Position

#df.iloc[:]  # Select all the row and Column in the dataframe
#df.iloc[1:5,] #Second to Fifith Row
#df.iloc[5,0] # Sixth row and 1st Column  output : single value (Cell value)
#df.iloc[1:5,0] # Second to Fifth row and First Column
#df.iloc[1:5,:5] # Second to Fifth row, first 5 Columns
#df.iloc[2:7,1:3] # Third to Seventh row,2nd and 3rd Column

# df.iloc[:5,] #First 5 rows
# df.iloc[1:5,] #Second to Fifth row
# df.iloc[5,0] #Sixth row and 1st column
# df.iloc[1:5,0] #Second to Fifth row, first column
# df.iloc[1:5,:5] #Second to Fifth row, first 5 columns
# df.iloc[2:7,1:3] #Third to Seventh row, 2nd and 3rd column

#  df.iloc[[index for index,row in df.iterrows() if row['origin'] == 'JFK' and row['carrier'] == 'B6']]

# %%
#isin

value_list = ["S","C"]
df[df.Embarked.isin(value_list)].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#isin

value_list = ["S","C"]
df[~ df.Embarked.isin(value_list)].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 5             6         0       3               Moran, Mr. James    male
# 16           17         0       3           Rice, Master. Eugene    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female
# 32           33         1       3       Glynn, Miss. Mary Agatha  female
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5    NaN      0      0  330877   8.4583   NaN        Q
# 16   2.0      4      1  382652  29.1250   NaN        Q
# 22  15.0      0      0  330923   8.0292   NaN        Q
# 28   NaN      0      0  330959   7.8792   NaN        Q
# 32   NaN      0      0  335677   7.7500   NaN        Q

# %%
# options = ['Commerce', 'Science'] 
# dataframe[dataframe['Stream'].isin(options)] 

# dataframe.loc[(dataframe['Age'] == 22) & dataframe['Stream'].isin(options)]

# %%
# query

df.query('Sex == "male" & Embarked == "S"').head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 6       0      0      17463  51.8625   E46        S
# 7       3      1     349909  21.0750   NaN        S
# 12      0      0  A/5. 2151   8.0500   NaN        S

# %%
import pandas as pd
df=pd.DataFrame({'Name':['JOHN','ALLEN','BOB','NIKI','CHARLIE','CHANG'],
              'Age':[35,42,63,29,47,51],
              'Salary_in_1000':[100,93,78,120,64,115],
             'FT_Team':['STEELERS','SEAHAWKS','FALCONS','FALCONS','PATRIOTS','STEELERS']})
df
# Out:
#       Name  Age  Salary_in_1000   FT_Team
# 0     JOHN   35             100  STEELERS
# 1    ALLEN   42              93  SEAHAWKS
# 2      BOB   63              78   FALCONS
# 3     NIKI   29             120   FALCONS
# 4  CHARLIE   47              64  PATRIOTS
# 5    CHANG   51             115  STEELERS

# %%
# Pandas Eval multiple conditions

df[df.eval("Salary_in_1000>=100 & (Age <60) & FT_Team.str.startswith('S').values")]
# Out:
#     Name  Age  Salary_in_1000   FT_Team
# 0   JOHN   35             100  STEELERS
# 5  CHANG   51             115  STEELERS

# %%
df.loc[np.where((df['Salary_in_1000']>=100) & (df['Age']< 60) & (df['FT_Team'].str.startswith('S')))]
# Out:
#     Name  Age  Salary_in_1000   FT_Team
# 0   JOHN   35             100  STEELERS
# 5  CHANG   51             115  STEELERS

# %%
df.loc[(df['Salary_in_1000']>=100) & (df['Age']< 60) & (df['FT_Team'].str.startswith('S')),['Name','FT_Team']]
# Out:
#     Name   FT_Team
# 0   JOHN  STEELERS
# 5  CHANG  STEELERS

# %%
# Select Non-Missing Data in Pandas Dataframe
#df[df.origin.notnull()]

# %%
# Lambda Method for Filtering
# list(filter(lambda x: x["origin"] == 'JFK' and x["carrier"] == 'B6', lst_df))

# List Comprehension Method for Filtering
# list(x for x in lst_df if x["origin"] == 'JFK' and x["carrier"] == 'B6')

# %%
# Lambda Methods

# list(filter(lambda x: x["origin"] == 'JFK' and x["carrier"] == 'B6', lst_df))
# df[df.apply(lambda x: x["origin"] == 'JFK' and x["carrier"] == 'B6', axis=1)]

# %%
# List Comprehension

# l2 = list(x for x in lst_df if x["origin"] == 'JFK' and x["carrier"] == 'B6')
# df.iloc[[index for index,row in df.iterrows() if row['origin'] == 'JFK' and row['carrier'] == 'B6']]
