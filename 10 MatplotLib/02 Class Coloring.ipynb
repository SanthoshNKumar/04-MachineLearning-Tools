# %%
# 01 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
import seaborn as sns
from sklearn import svm

from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=50, centers=2,random_state=0, cluster_std=0.60)
plt.scatter(X[:, 0], X[:, 1],c=y, s=50, cmap='autumn')

# %%
# 02 

import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

irirs = load_iris
df = pd.DataFrame(data= load_iris().data,columns=load_iris().feature_names)
df['output'] = load_iris().target

y = df['output']

plt.scatter(df['sepal length (cm)'][y ==0],df['sepal width (cm)'][y ==0],c ='b',Label = 'Iris-setosa',marker='*')
plt.scatter(df['sepal length (cm)'][y ==1],df['sepal width (cm)'][y ==1],c ='r',Label = 'Iris-versicolor',marker='o')
plt.scatter(df['sepal length (cm)'][y ==2],df['sepal width (cm)'][y ==2],c ='y',Label = 'Iris-virginica',marker='+')
plt.legend()
plt.grid()

# %%
# 03 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:\MyWork\MyLearning\Career Growth\ML\Files\Dataset\ex2data1.csv",header = None)

X_vals = df.iloc[:,0:2]
y_vals = df.iloc[:,-1]

plt.scatter(X_vals.iloc[:,0:1][y_vals==1],X_vals.iloc[:,1:2][y_vals==1],c='b',Label="Admited")
plt.scatter(X_vals.iloc[:,0:1][y_vals==0],X_vals.iloc[:,1:2][y_vals==0],c='r',Label="Not Admited")
plt.legend()
plt.xlabel("Exam 1 score")
plt.ylabel("Exam 2 score")
# Out:
# Text(0, 0.5, 'Exam 2 score')

# %%
#05 : Before and After Scaling

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

from sklearn.decomposition import PCA
iris = load_iris()
iris_X = iris.data
y = iris.target

iris_X_PCA = PCA(n_components=2).fit_transform(iris_X)

print(iris_X[0])
print(iris_X_PCA[0])

iris_X_Scaled = scale(iris_X)
iris_X_Scaled_PCA = PCA(n_components=2).fit_transform(iris_X_Scaled)

iris_X_Scaled_PCA[0]

fig,ax = plt.subplots(1,2,figsize=(15,5))

ax[0].scatter(iris_X_PCA[:,0],iris_X_PCA[:,1],c=y)
ax[0].set_title("PCA Before Scaling")

ax[1].scatter(iris_X_Scaled_PCA[:,0],iris_X_Scaled_PCA[:,1],c=y)
ax[1].set_title("PCA After Scaling")
# Out:
# [5.1 3.5 1.4 0.2]
# [-2.68412563  0.31939725]
# Text(0.5, 1.0, 'PCA After Scaling')

# %%
# 06 
import numpy as np
from sklearn.preprocessing import StandardScaler,normalize,MinMaxScaler
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris = load_iris().data

x = iris[:,0:2]
y = load_iris().target

# %%
plt.scatter(x[:,0][y==0],x[:,1][y==0],c='r')
plt.scatter(x[:,0][y==1],x[:,1][y==1],c='b')
plt.scatter(x[:,0][y==2],x[:,1][y==2],c='g')

# %%
# Stndarddize the data
x_standadize = StandardScaler().fit_transform(x)
plt.scatter(x_standadize[:,0][y==0],x_standadize[:,1][y==0],c='r')
plt.scatter(x_standadize[:,0][y==1],x_standadize[:,1][y==1],c='b')
plt.scatter(x_standadize[:,0][y==2],x_standadize[:,1][y==2],c='g')

# %%
x_normalizelL11 = normalize(x, norm='l1',axis=0) 
plt.scatter(x_normalizelL11[:,0][y==0],x_normalizelL11[:,1][y==0],c='r')
plt.scatter(x_normalizelL11[:,0][y==1],x_normalizelL11[:,1][y==1],c='b')
plt.scatter(x_normalizelL11[:,0][y==2],x_normalizelL11[:,1][y==2],c='g')
plt.xlim(0.0025,0.01)
plt.ylim(0.003,0.010)
# Out:
# (0.003, 0.01)

# %%
x_normalizelL12 = normalize(x, norm='l2',axis=0) 
plt.scatter(x_normalizelL12[:,0][y==0],x_normalizelL12[:,1][y==0],c='r')
plt.scatter(x_normalizelL12[:,0][y==1],x_normalizelL12[:,1][y==1],c='b')
plt.scatter(x_normalizelL12[:,0][y==2],x_normalizelL12[:,1][y==2],c='g')

# %%
x_MinMAxScling = MinMaxScaler(feature_range=(0, 1)).fit_transform(x)
plt.scatter(x_MinMAxScling[:,0][y==0],x_MinMAxScling[:,1][y==0],c='r')
plt.scatter(x_MinMAxScling[:,0][y==1],x_MinMAxScling[:,1][y==1],c='b')
plt.scatter(x_MinMAxScling[:,0][y==2],x_MinMAxScling[:,1][y==2],c='g')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
import seaborn as sns
from sklearn import svm

X = np.array([[1,2],
             [5,8],
             [1.5,1.8],
             [8,8],
             [1,0.6],
             [9,11]])

y = [0,1,0,1,0,1]

clf = svm.SVC(kernel='linear', C = 1.0)

clf.fit(X,y)

w = clf.coef_[0]
print(w)

a = -w[0] / w[1]

xx = np.linspace(0,12)
yy = a * xx - clf.intercept_[0] / w[1]

h0 = plt.plot(xx, yy, 'k-', label="non weighted div")

plt.scatter(X[:, 0], X[:, 1], c = y)
plt.legend()
plt.show()
# Out:
# [0.1380943  0.24462418]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs


# we create 40 separable points
X, y = make_blobs(n_samples=40, centers=2, random_state=6)

# fit the model, don't regularize for illustration purposes
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.show()
