# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

x = np.array([17, 13, 12, 15, 16, 14, 16, 16, 18, 19]) 
y = np.array([94, 73, 59, 80, 93, 85, 66, 79, 77, 91])


plt.hist(x)
# Out:
# (array([1., 1., 1., 0., 1., 3., 0., 1., 1., 1.]),
#  array([12. , 12.7, 13.4, 14.1, 14.8, 15.5, 16.2, 16.9, 17.6, 18.3, 19. ]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

df = pd.DataFrame(data= load_iris().data,columns=load_iris().feature_names)
df['output'] = load_iris().target

# %%
pd.DataFrame(df['sepal length (cm)']).hist()

pd.DataFrame(df['sepal length (cm)']).plot(kind='kde')

# %%
pd.DataFrame(df['sepal width (cm)']).hist()

pd.DataFrame(df['sepal width (cm)']).plot(kind='kde')

# %%
pd.DataFrame(df['petal length (cm)']).hist()

pd.DataFrame(df['petal length (cm)']).plot(kind='kde')

# %%
pd.DataFrame(df['petal width (cm)']).hist()

pd.DataFrame(df['petal width (cm)']).plot(kind='kde')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris= load_iris
df = pd.DataFrame(data= load_iris().data,columns=load_iris().feature_names)

df.plot.hist(subplots = True,layout=(3,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001848D490A88>,
# ...
#       dtype=object)
