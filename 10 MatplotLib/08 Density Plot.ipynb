# %% [markdown]
# # Parametric Density Estimation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

np.random.seed(10)
# generate a sample
sample = np.random.normal(loc=50, scale=5, size=1000)
# calculate parameters
sample_mean = np.mean(sample)
sample_std = np.std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))

# define the distribution
dist = norm(sample_mean, sample_std)

# sample probabilities for a range of outcomes
values = [value for value in range(30, 70)]

probabilities = [dist.pdf(value) for value in values]
# plot the histogram and pdf
plt.hist(sample, bins=10, density=True)
plt.plot(values, probabilities)
plt.show()
# Out:
# Mean=49.927, Standard Deviation=4.690

# %% [markdown]
# # Nonparametric Density Estimation

# %%
sample1 = np.random.normal(loc=20, scale=5, size=300)
sample2 = np.random.normal(loc=40, scale=5, size=700)

np.random.seed(10)

sample = np.hstack((sample1, sample2))

# plot the histogram
plt.hist(sample, bins=50)
plt.show()

# %%
from sklearn.neighbors import KernelDensity

model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
values = np.asarray([value for value in range(1, 60)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = np.exp(probabilities)

# plot the histogram and pdf
plt.hist(sample, bins=50, density=True)
plt.plot(values[:], probabilities)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.datasets import load_boston

df = pd.DataFrame(load_boston().data,columns=load_boston().feature_names)

from sklearn.neighbors import KernelDensity

model = KernelDensity(bandwidth=2, kernel='gaussian')

x = np.array(df.INDUS)

x = x.reshape((len(x), 1))
model.fit(x)
values = np.asarray([value for value in range(-10, 60)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = np.exp(probabilities)

#plt.hist(x, bins=50, density=True)
plt.plot(values[:], probabilities)
plt.show()

# %%
# Plot Using Matplot Lib
df.INDUS.plot(kind='kde')

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

load_iris().feature_names

df = pd.DataFrame(load_iris().data,columns=load_iris().feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
print(df['sepal length (cm)'].mean())
print(df['sepal width (cm)'].mean())
print(df['petal length (cm)'].mean())
print(df['petal width (cm)'].mean())
# Out:
# 5.843333333333334
# 3.0573333333333337
# 3.7580000000000005
# 1.1993333333333336

# %%
print(df['sepal length (cm)'].std())
print(df['sepal width (cm)'].std())
print(df['petal length (cm)'].std())
print(df['petal width (cm)'].std())
# Out:
# 0.828066127977863
# 0.4358662849366982
# 1.7652982332594662
# 0.7622376689603465

# %%
df['sepal length (cm)'].plot.kde()

# %%
df['sepal width (cm)'].plot.kde()

# %%
df['petal length (cm)'].plot.kde()

# %%
df['petal width (cm)'].plot.kde()

# %%
# Visualize_Seaborn_Density(kde)_RugPlot

# Rug plot : If you want to show every value in a distribution and not just the smoothed density, 
# you can add a rug plot. This shows every single data point on the x-axis, allowing us to visualize all of the actual values.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("tips.csv")

sns.distplot(df[df.day =='Sat'].total_bill,hist=False,rug=True,rug_kws={'color': 'black'})

# %%
# KDE for Multivariates

import numpy as np
import seaborn as sns
import pandas as pd

np.random.seed(1)

data1 = np.random.randn(100) + 50
data2 = np.random.randn(100) + 51

pd.DataFrame({'X1' : data1,'X2' :data2}).plot.kde()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris= load_iris
df = pd.DataFrame(data= load_iris().data,columns=load_iris().feature_names)

# %%
sns.distplot(df['sepal length (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['sepal width (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['petal length (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['petal width (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['sepal length (cm)'], bins=10, kde=True)
sns.distplot(df['sepal width (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['sepal length (cm)'], bins=10, kde=True)
sns.distplot(df['petal length (cm)'], bins=10, kde=True)

# %%
sns.distplot(df['sepal length (cm)'], bins=10, kde=True)
sns.distplot(df['petal width (cm)'], bins=10, kde=True)
