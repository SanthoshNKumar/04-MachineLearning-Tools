# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

data = pd.read_csv("C:\MyWork\MyLearning\Career Growth\ML\Files\Dataset\Salary_data.csv")

X = data.iloc[:,:-1]

y = data.iloc[:,-1]

plt.scatter(X,y)
plt.hlines(60000,2,8) # Draw Horizontal Line (y,Xlim)

plt.vlines(4,30000,100000) #Draw Verticle Line(x,Ylim)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


x = np.array([2,3,4,5,6,7,8])

y = np.array([4,5,7,9,10,11,13])

plt.scatter(x,y)

plt.axhline(x.mean()) # Horizontal line for average of X

plt.axvline(y.mean())# Vertical line for average of Y
